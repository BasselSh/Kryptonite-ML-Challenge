# %%
import os

import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import PIL 
from PIL import Image

import cv2

# %%
project_path = os.getcwd()
image_path = r'F:\Codenrock\Kryptonite\data\train\images'
#project_path

# %%
coords_df = pd.read_csv('points_df')
coords_df
# Out:
#        folder  image  left_eye_x  left_eye_y  right_eye_x  right_eye_y  \
# 0           0  0.jpg   70.293776   90.674323   151.365816    94.889114
# 1           0  1.jpg   69.580295   90.073405   156.717269   100.265060
# 2           0  2.jpg   82.465339  104.280702   142.471063   104.811607
# 3           0  3.jpg   80.448859  102.413674   140.424275   104.375992
# 4           0  4.jpg   71.584100   91.523647   151.622520    95.589734
# ...       ...    ...         ...         ...          ...          ...
# 97728    9999  4.jpg   83.923056  105.820967   138.782989   108.440058
# 97729    9999  5.jpg   74.329556   90.746301   154.508275    94.955056
# 97730    9999  6.jpg   83.271810  104.747291   138.957000   105.482776
# 97731    9999  7.jpg   71.405141   93.835775   153.594045    92.857850
# 97732    9999  8.jpg   85.336076  105.590511   139.711469   106.661673
#
#            nose_x      nose_y  left_mouth_x  left_mouth_y  right_mouth_x  \
# ...

# %%
def show_points(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    plt.imshow(img)
    plt.scatter(coord[::2], coord[1::2], s = 50, marker ='.', c='w')
    plt.axis('off');

# %%
show_points(project_path, '000000', '0.jpg', coords_df)

# %%
def full_eye_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = 0
    y = coord[1] - 20 # you may change the height
    width = 224
    height = 40 # you may change the height
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
full_eye_poligon(project_path, '000000', '0.jpg', coords_df)

# %%
def eye_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = coord[0] - 50 # you may change the width
    y = coord[1] - 20 # you may change the height
    width = coord[2] - coord[0] + 100 # you may change the width
    height = 40 # you may change the height
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
eye_poligon(project_path, '000000', '0.jpg', coords_df)

# %%
def nose_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = coord[4] - 30 # you may change the width
    y = coord[5] - 100 # you may change the height
    width = 60 # you may change the width
    height = 120 # you may change the height
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
nose_poligon(project_path, '000000', '0.jpg', coords_df)

# %%
def full_mouth_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = 0
    y = coord[7] - 20 # you may change the height
    width = 224
    height = 40 # you may change the height
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
full_mouth_poligon(project_path, '000000', '0.jpg', coords_df)

# %%
def part_mouth_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = coord[6] - 50 # you may change the width
    y = coord[7] - 20 # you may change the height
    width = coord[8] - coord[6] + 100 # you may change the width
    height = 40 # you may change the height
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
part_mouth_poligon(project_path, '000000', '0.jpg', coords_df)

# %%
def left_half_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = 0
    y = 0 
    width = 112
    height = 224 
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
left_half_poligon(project_path, '000000', '0.jpg', coords_df)

# %%
def right_half_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = 112
    y = 0 
    width = 112
    height = 224 
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
right_half_poligon(project_path, '000000', '0.jpg', coords_df)

# %%
def upper_half_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = 0
    y = 0 
    width = 224
    height = 112
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
upper_half_poligon(project_path, '000000', '0.jpg', coords_df)

# %%
def low_half_poligon(path, folder, name, df):
    img = Image.open(os.path.join(path, folder, name))
    coord = np.array(df.loc[(df['folder'] == int(folder)) & (df['image'] == name)])[0][2::]
    plt.figure(figsize = (6, 6))
    fig, ax = plt.subplots()
    plt.imshow(img)
    x = 0
    y = 112 
    width = 224
    height = 112
    rectangle = mpl.patches.Rectangle((x, y), width, height, linewidth=2, facecolor='black', lw=2)
    ax.add_patch(rectangle)
    plt.axis('off');

# %%
low_half_poligon(project_path, '000000', '0.jpg', coords_df)
